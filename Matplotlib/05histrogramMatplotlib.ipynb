# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ages = [
    18, 22, 19, 20, 23, 25, 27, 21, 24, 19, 17, 22, 22, 20, 26, 24, 18, 23, 21, 20,
    29, 30, 31, 33, 28, 34, 35, 37, 40, 42, 44, 45, 47, 46, 50, 52, 54, 55, 56, 58,
    60, 61, 62, 63, 65, 66, 67, 70, 72, 18, 19, 21, 23, 24, 25, 20, 22, 23, 27, 29,
    28, 31, 33, 32, 30, 29, 27, 25, 24, 22, 21, 20, 19, 18, 17, 22, 23, 24, 26, 28,
    30, 31, 32, 34, 35, 36, 38, 40, 42, 44, 45, 46, 48, 50, 53, 55, 58, 60, 61, 62,
    63, 65, 67, 69, 70, 71, 72, 73, 74, 75, 18, 19, 21, 23, 25, 27, 29, 31, 33, 35,
    37, 39, 41, 43, 45, 47, 49, 51, 53, 55, 57, 59, 61, 63, 65, 67, 69, 71, 73, 75,
    77, 79, 81, 83, 85, 87, 18, 20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44,
    46, 48, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76, 78, 80, 82, 84,
    86, 88, 18, 21, 23, 25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45, 47, 49, 51, 53,
    55, 57, 59, 61, 63, 65, 67, 69, 71, 73, 75, 77, 79, 81, 83, 85, 87, 89, 90
]

plt.hist(ages,bins=5,alpha=1,edgecolor='black')
plt.title("youtube (watching data by ages")
plt.xlabel("Age group")
plt.ylabel("number of viewrs")
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
ages = [
    18, 22, 19, 20, 23, 25, 27, 21, 24, 19, 17, 22, 22, 20, 26, 24, 18, 23, 21, 20,
    29, 30, 31, 33, 28, 34, 35, 37, 40, 42, 44, 45, 47, 46, 50, 52, 54, 55, 56, 58,
    60, 61, 62, 63, 65, 66, 67, 70, 72, 18, 19, 21, 23, 24, 25, 20, 22, 23, 27, 29,
    28, 31, 33, 32, 30, 29, 27, 25, 24, 22, 21, 20, 19, 18, 17, 22, 23, 24, 26, 28,
    30, 31, 32, 34, 35, 36, 38, 40, 42, 44, 45, 46, 48, 50, 53, 55, 58, 60, 61, 62,
    63, 65, 67, 69, 70, 71, 72, 73, 74, 75, 18, 19, 21, 23, 25, 27, 29, 31, 33, 35,
    37, 39, 41, 43, 45, 47, 49, 51, 53, 55, 57, 59, 61, 63, 65, 67, 69, 71, 73, 75,
    77, 79, 81, 83, 85, 87, 18, 20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44,
    46, 48, 50, 52, 54, 56, 58, 60, 62, 64, 66, 68, 70, 72, 74, 76, 78, 80, 82, 84,
    86, 88, 18, 21, 23, 25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45, 47, 49, 51, 53,
    55, 57, 59, 61, 63, 65, 67, 69, 71, 73, 75, 77, 79, 81, 83, 85, 87, 89, 90
]

plt.hist(ages,bins=5,alpha=0.8,edgecolor='black')
plt.title("youtube (watching data by ages")
plt.xlabel("Age group")
plt.ylabel("number of viewrs")
plt.axvline(np.mean(ages), color='red', linestyle='--', linewidth=2,
label='Average Age')
plt.tight_layout()
plt.legend()
plt.grid(True)
plt.show()

# %%
age2 = [
    # Teenagers
    17, 18, 18, 18, 19, 19, 19, 19,
    
    # Young Adults (20–30)
    20, 20, 20, 21, 21, 21, 22, 22, 22, 22, 23, 23, 23, 23, 24, 24, 24, 24, 
    25, 25, 25, 25, 26, 26, 27, 27, 27, 28, 28, 28, 29, 29, 29, 30, 30, 30, 30,

    # Middle Age (31–50)
    31, 31, 32, 32, 33, 33, 34, 34, 35, 35, 36, 36, 37, 37, 38, 38, 39, 39, 
    40, 40, 41, 41, 42, 42, 43, 43, 44, 44, 45, 45, 46, 46, 47, 47, 48, 48, 
    49, 49, 50, 50,

    # Older Adults (51–70)
    51, 52, 53, 54, 55, 55, 56, 57, 58, 58, 59, 60, 60, 61, 61, 62, 63, 64,
    65, 65, 66, 66, 67, 68, 69, 70,

    # Elderly (71–90)
    71, 72, 73, 74, 75, 75, 76, 77, 78, 78, 79, 80, 81, 82, 83, 84, 85, 85,
    86, 87, 88, 89, 90
]

# %%
plt.hist(age2,bins=5,alpha=1,edgecolor='black')
plt.title("youtube (watching data by ages")
plt.xlabel("Age group")
plt.ylabel("number of viewrs")
plt.tight_layout()
plt.grid(True)
plt.show()
