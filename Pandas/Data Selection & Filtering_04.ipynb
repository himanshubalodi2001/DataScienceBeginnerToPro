# %%
import pandas as pd

# %%
df=pd.read_csv("Data1.csv")
df
# Out:
#       Name  Gender  Age  Class   House  Unit Test 1  Unit Test 2  Final Test
# 0     Diya    Male   12      7    Agni           76           54         100
# 1     Myra    Male   16      9  Bhoomi           91           42          95
# 2    Ayaan  Female   15      8    Vayu           79           63          94
# 3   Ishaan    Male   14      9  Bhoomi           78           63          94
# 4    Rudra    Male   15      8     Jal           83           99          94
# 5    Ayaan  Female   14      9     Jal           50          100          87
# 6   Saanvi    Male   13      9    Agni           73           52          83
# 7    Anaya    Male   11      9    Agni           75           53          80
# 8   Saanvi    Male   11      7    Vayu           60           62          74
# 9     Myra    Male   14      8     Jal           42           55          73
# 10  Vivaan    Male   12      7     Jal           85           82          73
# ...

# %%
a=df['Name']
a
# Out:
# 0       Diya
# 1       Myra
# 2      Ayaan
# 3     Ishaan
# 4      Rudra
# 5      Ayaan
# 6     Saanvi
# 7      Anaya
# 8     Saanvi
# 9       Myra
# 10    Vivaan
# 11     Anaya
# 12     Aarav
# 13     Rudra
# 14    Vivaan
# 15      Diya
# 16     Rudra
# 17     Anaya
# 18    Vivaan
# 19    Saanvi
# Name: Name, dtype: object

# %%
df[["Name","Final Test"]]
# Out:
#       Name  Final Test
# 0     Diya         100
# 1     Myra          95
# 2    Ayaan          94
# 3   Ishaan          94
# 4    Rudra          94
# 5    Ayaan          87
# 6   Saanvi          83
# 7    Anaya          80
# 8   Saanvi          74
# 9     Myra          73
# 10  Vivaan          73
# 11   Anaya          68
# 12   Aarav          65
# 13   Rudra          65
# 14  Vivaan          64
# 15    Diya          63
# 16   Rudra          63
# 17   Anaya          58
# 18  Vivaan          52
# 19  Saanvi          48

# %%
df.loc[1]  # if a,b,c
# Out:
# Name             Myra
# Gender           Male
# Age                16
# Class               9
# House          Bhoomi
# Unit Test 1        91
# Unit Test 2        42
# Final Test         95
# Name: 1, dtype: object

# %%
df.iloc[1]  # index
# Out:
# Name             Myra
# Gender           Male
# Age                16
# Class               9
# House          Bhoomi
# Unit Test 1        91
# Unit Test 2        42
# Final Test         95
# Name: 1, dtype: object

# %%
df.loc[5,"Final Test"]
# Out:
# 87

# %%
df.iloc[5,4]
# Out:
# 'Jal'

# %%
df.loc[0:2,["Name","Gender","Final Test"]]
# Out:
#     Name  Gender  Final Test
# 0   Diya    Male         100
# 1   Myra    Male          95
# 2  Ayaan  Female          94

# %%
df.iloc[0:2,0:2]
# Out:
#    Name Gender
# 0  Diya   Male
# 1  Myra   Male

# %%
#for accesing the particular element at[]and iat[]

# %%
df.at[0,'Name']
# Out:
# 'Diya'

# %%
df.iat[0,0]
# Out:
# 'Diya'

# %%
df[df["Final Test"]>90]
# Out:
#      Name  Gender  Age  Class   House  Unit Test 1  Unit Test 2  Final Test
# 0    Diya    Male   12      7    Agni           76           54         100
# 1    Myra    Male   16      9  Bhoomi           91           42          95
# 2   Ayaan  Female   15      8    Vayu           79           63          94
# 3  Ishaan    Male   14      9  Bhoomi           78           63          94
# 4   Rudra    Male   15      8     Jal           83           99          94

# %%
df[df["Final Test"]>90] ["House"]
# Out:
# 0      Agni
# 1    Bhoomi
# 2      Vayu
# 3    Bhoomi
# 4       Jal
# Name: House, dtype: object

# %%
df[(df["Final Test"]>90) & ( df["Class"]==8)]
# Out:
#     Name  Gender  Age  Class House  Unit Test 1  Unit Test 2  Final Test
# 2  Ayaan  Female   15      8  Vayu           79           63          94
# 4  Rudra    Male   15      8   Jal           83           99          94

# %%
df.query("Age > 12 and Class > 8 ")
# Out:
#       Name  Gender  Age  Class   House  Unit Test 1  Unit Test 2  Final Test
# 1     Myra    Male   16      9  Bhoomi           91           42          95
# 3   Ishaan    Male   14      9  Bhoomi           78           63          94
# 5    Ayaan  Female   14      9     Jal           50          100          87
# 6   Saanvi    Male   13      9    Agni           73           52          83
# 11   Anaya  Female   16     10  Bhoomi           62           63          68
# 13   Rudra    Male   14     10    Vayu           61           51          65
# 15    Diya    Male   15      9  Bhoomi           80           66          63
# 19  Saanvi  Female   15      9  Bhoomi           82           71          48
